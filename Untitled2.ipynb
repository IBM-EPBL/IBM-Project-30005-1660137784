# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78ccdabc-627f-4036-8ebd-4e8828a69ca9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78ccdabc-627f-4036-8ebd-4e8828a69ca9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Churn_Modelling (1).csv')

# %%
import pandas as pd
path ='/content/Churn_Modelling (1).csv'

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df=pd.read_csv('Churn_Modelling (1).csv')

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['RowNumber'].plot.hist()

# %%
df['RowNumber'].plot.box()

# %%
df=pd.DataFrame({'Age':[42,41,42,39],'Tenure':[2,1,8,1]})
df.groupby('Age')['Tenure'].mean().plot.bar()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"]=[7.50,3.50]
plt.rcParams["figure.autolayout"]=True

def func(x,y):
    return 3*x+4 * y- 2+ np.random.randn(30)

x,y = np.random.randn(2,30)
y *=100
z = func(x,y)

fig,ax = plt.subplots()

s = ax.scatter(x,y, c=z,s=100,marker='.',cmap='plasma')

fig.colorbar(s)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame({'Age':[42,41,42,39]})
plt.hist(df)
plt.title("Histogram of Ages")
# Out:
# Text(0.5, 1.0, 'Histogram of Ages')

# %%
plt.boxplot(df)
plt.title("Boxplot of Ages")
# Out:
# Text(0.5, 1.0, 'Boxplot of Ages')

# %%
import pandas as pd

# %%
df.head()
# Out:
#    Age
# 0   42
# 1   41
# 2   42
# 3   39

# %%
df.shape
# Out:
# (4, 1)

# %%
df.isnull()
# Out:
#      Age
# 0  False
# 1  False
# 2  False
# 3  False

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Age
# 0  False
# 1  False
# 2  False
# 3  False>

# %%
df=pd.read_csv('Churn_Modelling (1).csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.DataFrame({'CustomerID':[15634602,15647311,15619304,15701354]})
plt.boxplot(df)
plt.title("Boxplot of CustomerId")
# Out:
# Text(0.5, 1.0, 'Boxplot of CustomerId')

# %%
df=pd.DataFrame({'Age':[42,41,42,39],'Tenure':[2,1,8,1]})
df.plot.scatter('Age','Tenure')

# %%
df=df[df['Tenure']<8]
df.plot.scatter('Age','Tenure')

# %%
df=pd.read_csv('Churn_Modelling (1).csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dummy=pd.get_dummies(df['Gender'])
dummy.head()
# Out:
#    Female  Male
# 0       1     0
# 1       1     0
# 2       1     0
# 3       1     0
# 4       1     0

# %%
df2=pd.concat((df,dummy),axis=1)
df2.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Female  Male
# 0        101348.88       1       1     0
# 1        112542.58       0       1     0
# ...

# %%
df2.drop(['Gender'],axis=1)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Age  Tenure  \
# 0             1    15634602   Hargrave          619    France   42       2
# 1             2    15647311       Hill          608     Spain   41       1
# 2             3    15619304       Onio          502    France   42       8
# 3             4    15701354       Boni          699    France   39       1
# 4             5    15737888   Mitchell          850     Spain   43       2
# ...         ...         ...        ...          ...       ...  ...     ...
# 9995       9996    15606229   Obijiaku          771    France   39       5
# 9996       9997    15569892  Johnstone          516    France   35      10
# 9997       9998    15584532        Liu          709    France   36       7
# 9998       9999    15682355  Sabbatini          772   Germany   42       3
# 9999      10000    15628319     Walker          792    France   28       4
#
# ...

# %%
df=pd.read_csv('Churn_Modelling (1).csv')
X =df.iloc[:,2:9]
Y =df.iloc[:,10]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('Churn_Modelling (1).csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X =df.drop(columns='Exited',axis=1)
Y =df['Exited']
print(X)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
print(Y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X_user,X_test,Y_user,Y_test=train_test_split(X,Y,test_size=0.2,random_state=4)
print(X.shape,X_user.shape,X_test.shape)
# Out:
# (10000, 13) (8000, 13) (2000, 13)
